# %%
import selfies as sf

# %%
smiles = "O=[N+]([O-])c1ccc(-c2nsc(-c3ccc([N+](=O)[O-])cc3)n2)cc1"
selfies = sf.encoder(smiles)
selfies
# Out:
# '[O][=N+1][Branch1][C][O-1][C][=C][C][=C][Branch2][Ring1][=Branch2][C][=N][S][C][Branch1][S][C][=C][C][=C][Branch1][=Branch1][N+1][=Branch1][C][=O][O-1][C][=C][Ring1][=Branch2][=N][Ring1][=C][C][=C][Ring2][Ring1][Ring2]'

# %%
selfies = "[C][=N][S][C]"
#parts_list = selfies.split()
smiles = sf.decoder(selfies)
smiles
# Out:
# 'C=NSC'
